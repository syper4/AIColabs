# %%
# !apt update

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ['PATH'] += ":/root/.cargo/bin"

# %%
# !pip install uv
# !git clone https://github.com/ace-step/ACE-Step-1.5.git
# %cd ACE-Step-1.5

# %%
# !uv sync

# %%
# !uv run acestep-download --all

# %%
# 1. Reset the file to its original state (undoing the previous sed)
#!git checkout /content/ACE-Step-1.5/acestep/acestep_v15_pipeline.py

# 2. Run the app with the --share flag
# Most Gradio-based CLI apps (like ACE-Step) support a --share argument naturally.
import os
os.environ['MPLBACKEND'] = 'Agg'
# !uv run acestep --share

# %%
#!npm install -g localtunnel

# %%
# Force Matplotlib to use the 'Agg' backend (safe for scripts/headless)
#!export MPLBACKEND=Agg && uv run acestep

#!lt --port 7860
#!curl https://loca.lt/mytunnelpassword

# %%
#!uv run acestep
